# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import flowermd

# %%
from flowermd.library import PPS
num_pps = 10
molecules = PPS(num_mols = num_pps , lengths=8)

# %%
from flowermd.base import Pack
system = Pack(molecules=molecules, density=0.5, packing_expand_factor=5)

# %%
from flowermd.library import OPLS_AA_PPS

system.apply_forcefield(r_cut=2.5, force_field=OPLS_AA_PPS(), auto_scale=True, scale_charges=True)
# Out:
# /home/danirojas/miniconda3/envs/flowermd/lib/python3.9/site-packages/gmso/core/topology.py:818: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   all_scales[index][scaling_interaction_idxes[interaction]] = value
# /home/danirojas/miniconda3/envs/flowermd/lib/python3.9/site-packages/gmso/core/topology.py:818: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   all_scales[index][scaling_interaction_idxes[interaction]] = value

# %%
system.hoomd_snapshot

# %%
hoomd_forces = system.hoomd_forcefield
hoomd_forces
# Out:
# [<hoomd.md.pair.pair.Ewald at 0x7fce5def03a0>,
#  <hoomd.md.long_range.pppm.Coulomb at 0x7fce5def5e20>,
#  <hoomd.md.special_pair.Coulomb at 0x7fce5def5bb0>,
#  <hoomd.md.pair.pair.LJ at 0x7fce5def1460>,
#  <hoomd.md.special_pair.LJ at 0x7fce5def9220>,
#  <hoomd.md.bond.Harmonic at 0x7fce5def3a90>,
#  <hoomd.md.angle.Harmonic at 0x7fce5df0d670>,
#  <hoomd.md.dihedral.OPLS at 0x7fce5ded3070>]

# %%
lj_force = hoomd_forces[3]

dict(lj_force.params)
# Out:
# {('ca',
#   'ca'): _HOOMDDict{'epsilon': 0.16470588235294115, 'sigma': 0.9861111111111112},
#  ('ca',
#   's'): _HOOMDDict{'epsilon': 0.37091488871610456, 'sigma': 0.9930312739844155},
#  ('ca',
#   'ha'): _HOOMDDict{'epsilon': 0.10782531046954916, 'sigma': 0.8141779918845362},
#  ('ca',
#   'sh'): _HOOMDDict{'epsilon': 0.40583972495671383, 'sigma': 0.9930312739844155},
#  ('ca', 'hs'): _HOOMDDict{'epsilon': 0.0, 'sigma': 0.0},
#  ('s', 's'): _HOOMDDict{'epsilon': 0.8352941176470587, 'sigma': 1.0},
#  ('ha',
#   's'): _HOOMDDict{'epsilon': 0.2428207934182387, 'sigma': 0.8198915917499229},
#  ('s', 'sh'): _HOOMDDict{'epsilon': 0.9139442639718566, 'sigma': 1.0},
#  ('hs', 's'): _HOOMDDict{'epsilon': 0.0, 'sigma': 0.0},
#  ('ha',
#   'ha'): _HOOMDDict{'epsilon': 0.07058823529411763, 'sigma': 0.6722222222222223},
#  ('ha',
#   'sh'): _HOOMDDict{'epsilon': 0.2656844656620285, 'sigma': 0.8198915917499229},
#  ('ha', 'hs'): _HOOMDDict{'epsilon': 0.0, 'sigma': 0.0},
#  ('sh', 'sh'): _HOOMDDict{'epsilon': 0.9999999999999999, 'sigma': 1.0},
#  ('hs', 'sh'): _HOOMDDict{'epsilon': 0.0, 'sigma': 0.0},
#  ('hs', 'hs'): _HOOMDDict{'epsilon': 0.0, 'sigma': 0.0}}

# %%
from flowermd.base import Simulation

sim = Simulation.from_system(system=system, gsd_write_freq=100, log_write_freq=100)
# Out:
# Initializing simulation state from a gsd.hoomd.Frame.

# %%
sim.run_update_volume(n_steps=1000, period=1, kT=1, tau_kt=1, final_box_lengths=system.target_box)
# Out:
# *Warning*: charge.pppm: RMS error of 0.500587 is probably too high! 0.500587 0.500484
# Step 100 of 1000; TPS: 213.88; ETA: 0.1 minutes
# Step 200 of 1000; TPS: 284.74; ETA: 0.0 minutes
# Step 300 of 1000; TPS: 316.59; ETA: 0.0 minutes
# Step 400 of 1000; TPS: 332.42; ETA: 0.0 minutes
# Step 500 of 1000; TPS: 339.17; ETA: 0.0 minutes
# Step 600 of 1000; TPS: 336.78; ETA: 0.0 minutes
# Step 700 of 1000; TPS: 335.34; ETA: 0.0 minutes
# Step 800 of 1000; TPS: 329.02; ETA: 0.0 minutes
# Step 900 of 1000; TPS: 309.29; ETA: 0.0 minutes
# Step 1000 of 1000; TPS: 277.31; ETA: 0.0 minutes

# %%
import hoomd
for writer in sim.operations.writers:
    if isinstance(writer, hoomd.write.GSD):
        writer.flush()

# %%
from cmeutils.visualize import FresnelGSD

sim_visualizer = FresnelGSD(gsd_file="trajectory.gsd", frame=0, view_axis=(1, 1, 1))
sim_visualizer.view()

# %%
sim_visualizer.frame = -1
sim_visualizer.view()

# %%
logger = hoomd.logging.Logger(categories=['scalar', 'string'])
logger.add(sim, quantities =['timestep', 'tps'])

# %%
file = open('log.txt', mode='w', newline='\n')

# %%
table_file = hoomd.write.Table(output=file,
                               trigger=hoomd.trigger.Periodic(period=500),
                               logger=logger)
sim.operations.writers.append(table_file)

# %%
sim.run_NVT(n_steps=10000, kT=1.0, tau_kt=0.01)
# Out:
# Step 99 of 10000; TPS: 141.0; ETA: 1.2 minutes
# Step 199 of 10000; TPS: 137.74; ETA: 1.2 minutes
# Step 299 of 10000; TPS: 137.7; ETA: 1.2 minutes
# Step 399 of 10000; TPS: 136.56; ETA: 1.2 minutes
# Step 499 of 10000; TPS: 138.56; ETA: 1.1 minutes
# Step 599 of 10000; TPS: 137.96; ETA: 1.1 minutes
# Step 699 of 10000; TPS: 138.43; ETA: 1.1 minutes
# Step 799 of 10000; TPS: 139.13; ETA: 1.1 minutes
# Step 899 of 10000; TPS: 139.68; ETA: 1.1 minutes
# Step 999 of 10000; TPS: 139.53; ETA: 1.1 minutes
# Step 1099 of 10000; TPS: 140.2; ETA: 1.1 minutes
# Step 1199 of 10000; TPS: 141.09; ETA: 1.0 minutes
# Step 1299 of 10000; TPS: 141.6; ETA: 1.0 minutes
# Step 1399 of 10000; TPS: 141.56; ETA: 1.0 minutes
# Step 1499 of 10000; TPS: 142.01; ETA: 1.0 minutes
# Step 1599 of 10000; TPS: 142.52; ETA: 1.0 minutes
# Step 1699 of 10000; TPS: 142.82; ETA: 1.0 minutes
# Step 1799 of 10000; TPS: 143.38; ETA: 1.0 minutes
# Step 1899 of 10000; TPS: 143.83; ETA: 0.9 minutes
# Step 1999 of 10000; TPS: 144.26; ETA: 0.9 minutes
# Step 2099 of 10000; TPS: 144.17; ETA: 0.9 minutes
# Step 2199 of 10000; TPS: 144.48; ETA: 0.9 minutes
# Step 2299 of 10000; TPS: 144.55; ETA: 0.9 minutes
# Step 6999 of 10000; TPS: 151.25; ETA: 0.3 minutes
# Step 7099 of 10000; TPS: 151.29; ETA: 0.3 minutes
# Step 7199 of 10000; TPS: 151.37; ETA: 0.3 minutes
# Step 7299 of 10000; TPS: 151.45; ETA: 0.3 minutes
# Step 7399 of 10000; TPS: 151.52; ETA: 0.3 minutes
# Step 7499 of 10000; TPS: 151.64; ETA: 0.3 minutes
# Step 7599 of 10000; TPS: 151.73; ETA: 0.3 minutes
# Step 7699 of 10000; TPS: 151.75; ETA: 0.3 minutes
# Step 7799 of 10000; TPS: 151.89; ETA: 0.2 minutes
# Step 7899 of 10000; TPS: 151.98; ETA: 0.2 minutes
# Step 7999 of 10000; TPS: 152.04; ETA: 0.2 minutes
# Step 8099 of 10000; TPS: 152.15; ETA: 0.2 minutes
# Step 8199 of 10000; TPS: 152.22; ETA: 0.2 minutes
# Step 8299 of 10000; TPS: 152.24; ETA: 0.2 minutes
# Step 8399 of 10000; TPS: 152.37; ETA: 0.2 minutes
# Step 8499 of 10000; TPS: 152.47; ETA: 0.2 minutes
# Step 8599 of 10000; TPS: 152.57; ETA: 0.2 minutes
# Step 8699 of 10000; TPS: 152.62; ETA: 0.1 minutes
# Step 8799 of 10000; TPS: 152.67; ETA: 0.1 minutes
# Step 8899 of 10000; TPS: 152.78; ETA: 0.1 minutes
# Step 8999 of 10000; TPS: 152.88; ETA: 0.1 minutes
# Step 9099 of 10000; TPS: 152.99; ETA: 0.1 minutes
# Step 9199 of 10000; TPS: 153.09; ETA: 0.1 minutes
# Step 9299 of 10000; TPS: 153.18; ETA: 0.1 minutes
# Step 9399 of 10000; TPS: 153.26; ETA: 0.1 minutes
# Step 9499 of 10000; TPS: 153.29; ETA: 0.1 minutes
# Step 9599 of 10000; TPS: 153.25; ETA: 0.0 minutes
# Step 9699 of 10000; TPS: 153.26; ETA: 0.0 minutes
# Step 9799 of 10000; TPS: 153.33; ETA: 0.0 minutes
# Step 9899 of 10000; TPS: 153.38; ETA: 0.0 minutes
# Step 9999 of 10000; TPS: 153.44; ETA: 0.0 minutes

# %%
# !cat log.txt
# Out:
# flowermd.base.simulation.Simulation.timestep flowermd.base.simulation.Simulation.tps
#                     1500                                    138.63822
#                     2000                                    139.58374
#                     2500                                    142.03421
#                     3000                                    144.27739
#                     3500                                    144.98341
#                     4000                                    146.20898
#                     4500                                    147.86252
#                     5000                                    148.41151
#                     5500                                    148.63401
#                     6000                                    149.16184
#                     6500                                    149.60386
#                     7000                                    150.07385
#                     7500                                    150.69616
#                     8000                                    151.25397
#                     8500                                    151.64631
#                     9000                                    152.04487
#                     9500                                    152.47831
#                    10000                                    152.88659
#                    10500                                    153.29507
#                    11000                                    153.43886

# %%
import numpy as np
numbers = np.loadtxt('log.txt', usecols=(1), skiprows=(1))
average_tps = np.mean(numbers)
print("Average TPS for n = ",num_pps, "is", average_tps, ".")
# Out:
# Average TPS for n =  10 is 148.36068400000002 .

# %%
for writer in sim.operations.writers:
    if isinstance(writer, hoomd.write.GSD):
        writer.flush()

# %%
sim_visualizer.frame=-1
sim_visualizer.view()
